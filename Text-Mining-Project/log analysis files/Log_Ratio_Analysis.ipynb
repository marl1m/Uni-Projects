# %% [markdown]
# # Log Ratio Analysis
# ### Group 03:
# - Catarina Oliveira | 20211616
# - Daniel Kruk | 20211687
# - Joana Rosa | 20211516
# - Marcelo Junior | 20211677
# - Martim Serra | 20211543
#
# ##### This notebook includes:
#  - Preparation of the dataset after it was treated in the preprocessing stage for the log_ratio analysis;
#
#  - Creating a powerfull vocabulary that reflects the characteristics of each tag;
#
#  - Exporting the vocabulary chosen;

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

from functions import *

import json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Martin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\Martin\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# DONE

# %% [markdown]
# # Data Download

# %%
data = pd.read_csv(
    'data/preproc_final/train_preproc.csv', index_col= 'id').loc[:,['lyrics', 'tag']].copy()

# %% [markdown]
# # Log Ratio Analysis
# #### Getting some `lyrics` insights

# %%
n = 3000
most_common_lyrics, tags, total_words_tag, total_words, top_words = prep_data(data,
                                                                              'lyrics',
                                                                              'tag',
                                                                               n = n)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Martin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\Martin\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# DONE
#
# Most Common Keys:
#  [('get', 417062), ('like', 286100), ('know', 264743), ('go', 221786), ('love', 180760), ('say', 165295), ('yeah', 163217), ('make', 153830), ('na', 153365), ('see', 140957), ('come', 140146), ('oh', 137772), ('time', 135974), ('one', 130919), ('feel', 122917), ('take', 121190), ('want', 117476), ('never', 115856), ('let', 111408), ('shall', 104478), ('back', 103086), ('im', 102378), ('nigga', 100956), ('think', 100605), ('fuck', 97529), ('tell', 96352), ('way', 91657), ('good', 90466), ('give', 85913), ('would', 85832), ('need', 85820), ('wan', 85639), ('u', 83184), ('life', 80847), ('baby', 79138), ('look', 78800), ('bitch', 77165), ('day', 77046), ('gon', 75174), ('man', 74880), ('could', 72729), ('shit', 72443), ('keep', 71923), ('right', 70793), ('leave', 70524), ('girl', 60763), ('thing', 59527), ('away', 58438), ('try', 58294), ('still', 58294), ('night', 57926), ('dont', 56745), ('heart', 56372), ('cause', 55465), ('call', 55111), ('find', 54884), ('live', 54343), ('run', 52653), ('mind', 50384), ('eye', 49381), ('break', 48300), ('world', 47718), ('every', 47026), ('even', 46593), ('put', 44587), ('always', 44484), ('lose', 44421), ('light', 44215), ('hear', 43617), ('really', 43223), ('hold', 42878), ('around', 41827), ('long', 41656), ('turn', 41378), ('talk', 40978), ('head', 40435), ('well', 40370), ('stay', 40273), ('hand', 40095), ('money', 40080), ('fall', 39937), ('little', 39276), ('nothing', 38930), ('play', 37624), ('ever', 37411), ('god', 37309), ('new', 37246), ('dream', 37099), ('face', 36330), ('em', 36318), ('stop', 36198), ('show', 36151), ('wait', 35733), ('boy', 35452), ('die', 35352), ('ya', 35261), ('hook', 34222), ('home', 33796), ('people', 33782), ('end', 33737), ('real', 33286), ('much', 33094), ('bad', 32959), ('high', 32896), ('hard', 32596), ('hit', 32458), ('everything', 32309), ('something', 31940), ('start', 31492), ('mean', 31333), ('walk', 31322), ('lie', 31260), ('ooh', 31106), ('change', 30863), ('move', 30848), ('friend', 30846), ('work', 28864), ('place', 28860), ('big', 28571), ('use', 28310), ('watch', 28237), ('name', 28236), ('alone', 28094), ('another', 28058), ('two', 27874), ('word', 27521), ('believe', 27351), ('hey', 27190), ('last', 27131), ('uh', 26714), ('old', 26375), ('stand', 26369), ('bring', 26332), ('might', 25909), ('yo', 25783), ('inside', 25272), ('do', 24534), ('cry', 24171), ('soul', 24147), ('close', 24005), ('kill', 23649), ('care', 23274), ('body', 23193), ('bout', 23188), ('please', 23135), ('la', 23121), ('bridge', 22956), ('without', 22952), ('beat', 22515), ('side', 22453), ('pre', 22329), ('tryna', 22224), ('game', 22173), ('pull', 22151), ('first', 21945), ('year', 21820), ('song', 21663), ('fight', 21614), ('pain', 21558), ('ask', 21455), ('free', 21413), ('black', 21388), ('best', 21107), ('hope', 20993), ('dance', 20963), ('fire', 20882), ('burn', 20876), ('miss', 20519), ('tonight', 20490), ('wrong', 20386), ('fly', 20360), ('catch', 20321), ('wish', 20266), ('star', 20235), ('sing', 20223), ('ah', 20185), ('mine', 20151), ('cant', 20097), ('young', 19886), ('outro', 19701), ('cold', 19668), ('hate', 19644), ('enough', 19601), ('sleep', 19410), ('aint', 19274), ('intro', 19163), ('many', 19114), ('maybe', 19005), ('far', 18974), ('roll', 18865), ('dead', 18815), ('seem', 18762), ('line', 18746), ('ill', 18636), ('sky', 18568), ('as', 18270), ('must', 18256), ('shoot', 18161), ('open', 18108), ('sun', 18075), ('help', 18045), ('drink', 17976), ('remember', 17871), ('smoke', 17869), ('forget', 17853), ('x', 17848), ('ride', 17814), ('though', 17665), ('drop', 17530), ('true', 17458), ('tear', 17322), ('thats', 17292), ('speak', 17286), ('whole', 17255), ('deep', 17172), ('street', 17086), ('rock', 17040), ('damn', 17036), ('door', 17030), ('round', 17013), ('sit', 16914), ('grow', 16903), ('pay', 16757), ('youre', 16757), ('sound', 16556), ('great', 16523), ('yes', 16485), ('meet', 16390), ('blow', 16378), ('till', 16274), ('grind', 16156), ('nobod ...
#
# Dictionary containing fdsits for each tag:
#  {'rock': FreqDist({'get': 34235, 'know': 29584, 'go': 27805, 'like': 22007, 'love': 20267, 'time': 20261, 'come': 19871, 'oh': 19394, 'see': 19282, 'one': 18299, ...}), 'rap': FreqDist({'get': 236592, 'like': 162600, 'know': 104398, 'nigga': 94773, 'yeah': 89886, 'go': 83157, 'fuck': 76957, 'bitch': 70014, 'im': 67033, 'make': 63312, ...}), 'pop': FreqDist({'get': 102946, 'know': 91126, 'love': 87122, 'go': 77486, 'oh': 73880, 'like': 69652, 'na': 61798, 'say': 52931, 'come': 51234, 'time': 49855, ...}), 'country': FreqDist({'get': 8083, 'love': 5374, 'know': 5271, 'go': 5065, 'like': 4236, 'say': 3391, 'shall': 3281, 'time': 3235, 'oh': 3139, 'one': 3118, ...}), 'rb': FreqDist({'get': 22489, 'know': 19443, 'love': 19056, 'yeah': 15446, 'like': 12973, 'oh': 12791, 'baby': 12353, 'na': 12030, 'go': 11382, 'say': 9779, ...}), 'misc': FreqDist({'say': 22763, 'one': 17748, 'go': 16891, 'know': 14921, 'would': 14871, 'like': 14632, 'make': 14041, 'come': 14032, 'get': 12717, 'see': 11507, ...})}
#
# Top 3000:
#  {'rock': [('get', 34235), ('know', 29584), ('go', 27805), ('like', 22007), ('love', 20267), ('time', 20261), ('come', 19871), ('oh', 19394), ('see', 19282), ('one', 18299), ('say', 18200), ('na', 17694), ('take', 17494), ('shall', 17482), ('feel', 17383), ('never', 16906), ('make', 16864), ('want', 15195), ('let', 14365), ('way', 13119), ('life', 12769), ('back', 12685), ('away', 12665), ('think', 12035), ('leave', 11430), ('day', 11301), ('would', 11298), ('yeah', 11211), ('u', 10418), ('tell', 10205), ('good', 10021), ('give', 9885), ('eye', 9749), ('could', 9578), ('look', 9501), ('find', 9346), ('need', 9257), ('night', 9074), ('live', 8969), ('heart', 8767), ('keep', 8664), ('world', 8568), ('thing', 8340), ('try', 8232), ('lose', 8198), ('mind', 8145), ('break', 8070), ('fall', 8065), ('gon', 7946), ('right', 7799), ('wan', 7606), ('run', 7523), ('still', 7458), ('im', 7449), ('nothing', 7419), ('light', 7374), ('die', 7254), ('well', 7071), ('end', 6997), ('baby', 6701), ('long', 6538), ('fuck', 6420), ('hand', 6389), ('head', 6372), ('dream', 6342), ('every', 6323), ('man', 6287), ('hear', 6282), ('hold', 6192), ('always', 6191), ('around', 6187), ('turn', 6146), ('call', 6088), ('lie', 6057), ('wait', 5966), ('home', 5842), ('burn', 5835), ('inside', 5712), ('everything', 5578), ('alone', 5576), ('face', 5439), ('dont', 5207), ('ever', 5099), ('something', 5035), ('stay', 4976), ('bridge', 4824), ('walk', 4793), ('god', 4713), ('soul', 4707), ('another', 4680), ('stand', 4655), ('little', 4652), ('place', 4631), ('pre', 4469), ('change', 4459), ('fire', 4388), ('word', 4361), ('believe', 4343), ('cause', 4338), ('stop', 4322), ('last', 4308), ('dead', 4272), ('fight', 4267), ('much', 4258), ('girl', 4181), ('friend', 4167), ('even', 4163), ('cry', 4052), ('start', 4029), ('hey', 3989), ('watch', 3975), ('new', 3939), ('pain', 3935), ('blood', 3926), ('show', 3919), ('mean', 3916), ('hard', 3840), ('bring', 3814), ('sky', 3811), ('la', 3810), ('sun', 3791), ('high', 3682), ('free', 3674), ('close', 3592), ('outro', 3591), ('far', 3555), ('tonight', 3545), ('play', 3528), ('ooh', 3518), ('old', 3503), ('sing', 3498), ('death', 3492), ('care', 3469), ('without', 3462), ('really', 3458), ('tear', 3425), ('kill', 3410), ('dark', 3407), ('fear', 3405), ('dance', 3394), ('hope', 3392), ('move', 3373), ('sleep', 3347), ('name', 3347), ('put', 3282), ('wrong', 3270), ('please', 3269), ('star', 3256), ('black', 3241), ('people', 3215), ('cold', 3214), ('bad', 3208), ('forget', 3185), ('maybe', 3058), ('youre', 3058), ('use', 3054), ('enough', 3029), ('hide', 2986), ('talk', 2983), ('line', 2976), ('hate', 2960), ('rise', 2951), ('song', 2920), ('seem', 2918), ('open', 2916), ('do', 2916), ('year', 2909), ('hell', 2908), ('wish', 2849), ('side', 2829), ('deep', 2795), ('save', 2788), ('ah', 2784), ('mine', 2782), ('help', 2770), ('forever', 2753), ('cant', 2733), ('behind', 2692), ('must', 2629), ('remember', 2613), ('alive', 2604), ('someone', 2572), ('grow', 2561), ('two', 2559), ('body', 2548), ('ill', 2540), ('sound', 2530), ('grind', 2490), ('blue', 2488), ('truth', 2487), ('door', 2421), ('wake', 2366), ('rain', 2346), ('wall', 2333), ('set', 2316), ('fade', 2308), ('rock', 2295), ('real', 2288), ('best', 2266), ('true', 2251), ('waste', 2244), ('work', 2233), ('ask', 2204), ('fly', 2199), ('drink', 2197), ('boy', 2190), ('bear', 2166), ('yes', 2149), ('become', 2149), ('speak', 2144), ('breathe', 2143), ('late', 2125), ('war', 2115), ('miss', 2112), ('scream', 2109), ('smile', 2107), ('might', 2099), ('meet', 2087), ('big', 2058), ('wind', 2055), ('roll', 2053), ('alright', 2040), ('many', 2027), ('begin', 2027), ('voice', 2025), ('ive', 2019), ('follow', 2004), ('past', 2001), ('catch', 1987), ('lay', 1972), ('control', 1961), ('beat', 1950), ('first', 1947), ('fine', 1925), ('child', 1918), ('else', 1901), ('street', 1899), ('cut', 1893), ('learn', 1891), ('hurt', 1890), ('reason', 1885), ('everyone', 1885), ('today',  ...
#
# Genre: pop
# Top 3000: [('get', 102946), ('know', 91126), ('love', 87122), ('go', 77486), ('oh', 73880), ('like', 69652), ('na', 61798), ('say', 52931), ('come', 51234), ('time', 49855), ('feel', 49249), ('make', 48536), ('see', 47058), ('shall', 44896), ('one', 44330), ('want', 43497), ('let', 43179), ('yeah', 42245), ('never', 41543), ('take', 41231), ('way', 34525), ('baby', 33919), ('think', 32363), ('would', 31891), ('tell', 31123), ('back', 30900), ('good', 30176), ('need', 29893), ('wan', 29888), ('day', 28564), ('give', 28487), ('u', 27960), ('could', 27331), ('heart', 27274), ('life', 27115), ('away', 26400), ('night', 25186), ('look', 25015), ('leave', 24819), ('gon', 24617), ('right', 24109), ('keep', 22672), ('thing', 22364), ('find', 22262), ('girl', 20520), ('try', 20216), ('eye', 20201), ('world', 19676), ('im', 19517), ('live', 18625), ('still', 18178), ('mind', 18071), ('fall', 17947), ('run', 17416), ('hold', 17355), ('break', 17330), ('light', 17219), ('lose', 16824), ('every', 16817), ('dream', 16320), ('call', 16320), ('man', 16201), ('long', 15889), ('always', 15855), ('around', 15188), ('ooh', 15088), ('nothing', 14900), ('little', 14883), ('hear', 14875), ('turn', 14870), ('hand', 14295), ('well', 14258), ('wait', 14215), ('ever', 14119), ('cause', 14088), ('home', 14032), ('stay', 14014), ('dont', 13629), ('la', 13131), ('everything', 12942), ('even', 12540), ('something', 12517), ('head', 12392), ('hey', 12321), ('alone', 12290), ('stop', 12052), ('end', 12008), ('lie', 11764), ('walk', 11630), ('pre', 11591), ('really', 11509), ('show', 11470), ('believe', 11431), ('face', 11193), ('much', 11089), ('change', 11040), ('place', 10952), ('die', 10933), ('play', 10835), ('tonight', 10793), ('dance', 10708), ('friend', 10679), ('new', 10514), ('cry', 10509), ('high', 10444), ('inside', 10349), ('move', 10347), ('god', 10287), ('start', 10268), ('sing', 10239), ('put', 10193), ('talk', 10189), ('hard', 10173), ('close', 10164), ('stand', 9964), ('bad', 9729), ('word', 9700), ('another', 9627), ('fuck', 9553), ('boy', 9546), ('last', 9545), ('mean', 9489), ('ah', 9410), ('bridge', 9084), ('people', 8999), ('please', 8712), ('name', 8551), ('without', 8538), ('soul', 8514), ('care', 8466), ('sky', 8448), ('sun', 8399), ('star', 8379), ('song', 8360), ('mine', 8328), ('free', 8271), ('old', 8182), ('maybe', 8138), ('bring', 8056), ('watch', 7998), ('burn', 7993), ('wrong', 7905), ('fight', 7905), ('wish', 7865), ('fire', 7708), ('ya', 7689), ('use', 7597), ('enough', 7546), ('tear', 7466), ('miss', 7432), ('side', 7412), ('body', 7387), ('forever', 7335), ('forget', 7315), ('far', 7303), ('fly', 7299), ('two', 7243), ('true', 7123), ('someone', 7114), ('hope', 7102), ('real', 7091), ('pain', 6987), ('work', 6966), ('seem', 6950), ('remember', 6744), ('sleep', 6702), ('together', 6702), ('kiss', 6696), ('do', 6580), ('youre', 6558), ('cold', 6467), ('blue', 6443), ('open', 6400), ('big', 6338), ('might', 6325), ('year', 6294), ('smile', 6281), ('rain', 6250), ('sweet', 6246), ('help', 6235), ('hurt', 6183), ('dark', 6170), ('best', 6141), ('deep', 6138), ('money', 6121), ('outro', 6110), ('hide', 6051), ('touch', 5986), ('yes', 5976), ('sound', 5882), ('da', 5783), ('ask', 5778), ('line', 5749), ('nobody', 5671), ('lord', 5632), ('meet', 5621), ('grow', 5562), ('door', 5523), ('alright', 5516), ('must', 5513), ('wake', 5503), ('rise', 5442), ('beat', 5419), ('kill', 5412), ('ill', 5363), ('cant', 5363), ('everybody', 5346), ('fear', 5297), ('save', 5292), ('late', 5271), ('shit', 5234), ('catch', 5231), ('speak', 5214), ('drink', 5167), ('else', 5132), ('round', 5115), ('fine', 5109), ('first', 5104), ('behind', 5030), ('uh', 5026), ('many', 5002), ('till', 4984), ('hit', 4964), ('matter', 4962), ('black', 4946), ('alive', 4896), ('wonder', 4882), ('morning', 4857), ('rock', 4850), ('listen', 4843), ('crazy', 4839), ('today', 4837), ('dead', 4805), ('hate', 4770), ('grind', 4767), ('game', 4757), ('sit', 4719), ('understan ...
#
# Genre: rap
# Top 3000: [('get', 236592), ('like', 162600), ('know', 104398), ('nigga', 94773), ('yeah', 89886), ('go', 83157), ('fuck', 76957), ('bitch', 70014), ('im', 67033), ('make', 63312), ('shit', 62122), ('say', 58231), ('na', 56418), ('see', 53932), ('back', 45944), ('come', 44835), ('time', 43977), ('take', 43119), ('never', 42986), ('want', 42387), ('love', 42204), ('feel', 41933), ('one', 41316), ('tell', 40006), ('wan', 38552), ('man', 38532), ('think', 38231), ('let', 38032), ('need', 34741), ('gon', 34530), ('good', 32755), ('give', 32700), ('keep', 31385), ('cause', 31083), ('dont', 30971), ('life', 30582), ('u', 30459), ('look', 30082), ('way', 29468), ('money', 28602), ('em', 28595), ('hook', 27661), ('right', 26837), ('shall', 25364), ('put', 24470), ('girl', 24457), ('oh', 24451), ('still', 24003), ('call', 23992), ('day', 23675), ('hit', 23420), ('ya', 23223), ('leave', 23067), ('baby', 23052), ('try', 23001), ('really', 22681), ('talk', 22308), ('run', 21851), ('yo', 21580), ('could', 21315), ('would', 20832), ('even', 20738), ('real', 20157), ('live', 19514), ('boy', 19034), ('tryna', 18511), ('uh', 18494), ('play', 18206), ('break', 17174), ('thing', 16894), ('big', 16856), ('stay', 16633), ('bout', 16552), ('mind', 16505), ('new', 16395), ('every', 15894), ('always', 15743), ('head', 15619), ('god', 15597), ('stop', 15585), ('bad', 15434), ('as', 14984), ('aint', 14948), ('show', 14928), ('hear', 14777), ('around', 14717), ('hard', 14551), ('night', 14238), ('lose', 13988), ('pull', 13943), ('face', 13850), ('people', 13757), ('turn', 13727), ('high', 13672), ('light', 13531), ('game', 13439), ('find', 13350), ('die', 13221), ('hoe', 13155), ('lil', 13141), ('smoke', 13114), ('start', 13070), ('beat', 13035), ('move', 12957), ('watch', 12838), ('work', 12831), ('intro', 12803), ('rap', 12648), ('kill', 12490), ('world', 12098), ('hold', 12066), ('might', 11935), ('shoot', 11843), ('ever', 11824), ('heart', 11706), ('damn', 11557), ('use', 11550), ('thats', 11470), ('eye', 11317), ('mean', 11310), ('name', 10964), ('two', 10953), ('change', 10777), ('away', 10769), ('hand', 10763), ('wait', 10738), ('catch', 10730), ('friend', 10687), ('do', 10675), ('fuckin', 10571), ('drop', 10563), ('x', 10502), ('nothing', 10355), ('hate', 10301), ('top', 10287), ('walk', 10214), ('much', 10209), ('little', 10119), ('roll', 10091), ('dream', 10067), ('pop', 10008), ('young', 9984), ('black', 9973), ('end', 9751), ('long', 9737), ('bring', 9516), ('aye', 9504), ('yea', 9456), ('everything', 9455), ('kid', 9443), ('cant', 9405), ('lie', 9371), ('check', 9282), ('ride', 9126), ('pay', 9126), ('ayy', 9116), ('blow', 9018), ('best', 8938), ('whole', 8933), ('body', 8925), ('ama', 8849), ('fall', 8821), ('cuz', 8799), ('street', 8764), ('well', 8686), ('flow', 8685), ('something', 8644), ('dick', 8615), ('bag', 8557), ('ask', 8520), ('stick', 8492), ('another', 8467), ('huh', 8376), ('fly', 8232), ('home', 8173), ('rock', 8168), ('pain', 8136), ('word', 8097), ('ill', 8035), ('lot', 8029), ('pussy', 7995), ('gang', 7984), ('throw', 7965), ('last', 7919), ('side', 7918), ('eat', 7885), ('first', 7876), ('care', 7759), ('wit', 7681), ('outro', 7677), ('please', 7559), ('drink', 7547), ('old', 7521), ('hope', 7501), ('cold', 7482), ('dead', 7482), ('act', 7449), ('everybody', 7400), ('yuh', 7381), ('line', 7377), ('hop', 7292), ('soul', 7226), ('hey', 7140), ('round', 7108), ('though', 7108), ('hot', 7104), ('miss', 7101), ('till', 7100), ('crazy', 7093), ('ooh', 7034), ('believe', 7017), ('place', 7006), ('block', 6986), ('song', 6878), ('write', 6868), ('city', 6835), ('many', 6834), ('mad', 6777), ('inside', 6768), ('fight', 6751), ('listen', 6750), ('nobody', 6692), ('grind', 6647), ('imma', 6645), ('gun', 6644), ('year', 6609), ('sleep', 6592), ('low', 6523), ('stand', 6491), ('cut', 6444), ('straight', 6422), ('next', 6405), ('free', 6387), ('nah', 6353), ('phone', 6261), ('close', 6223), ('sit', 6214), ('wrong', 6212), ('cash', 620 ...
#
# Genre: rock
# Top 3000: [('get', 34235), ('know', 29584), ('go', 27805), ('like', 22007), ('love', 20267), ('time', 20261), ('come', 19871), ('oh', 19394), ('see', 19282), ('one', 18299), ('say', 18200), ('na', 17694), ('take', 17494), ('shall', 17482), ('feel', 17383), ('never', 16906), ('make', 16864), ('want', 15195), ('let', 14365), ('way', 13119), ('life', 12769), ('back', 12685), ('away', 12665), ('think', 12035), ('leave', 11430), ('day', 11301), ('would', 11298), ('yeah', 11211), ('u', 10418), ('tell', 10205), ('good', 10021), ('give', 9885), ('eye', 9749), ('could', 9578), ('look', 9501), ('find', 9346), ('need', 9257), ('night', 9074), ('live', 8969), ('heart', 8767), ('keep', 8664), ('world', 8568), ('thing', 8340), ('try', 8232), ('lose', 8198), ('mind', 8145), ('break', 8070), ('fall', 8065), ('gon', 7946), ('right', 7799), ('wan', 7606), ('run', 7523), ('still', 7458), ('im', 7449), ('nothing', 7419), ('light', 7374), ('die', 7254), ('well', 7071), ('end', 6997), ('baby', 6701), ('long', 6538), ('fuck', 6420), ('hand', 6389), ('head', 6372), ('dream', 6342), ('every', 6323), ('man', 6287), ('hear', 6282), ('hold', 6192), ('always', 6191), ('around', 6187), ('turn', 6146), ('call', 6088), ('lie', 6057), ('wait', 5966), ('home', 5842), ('burn', 5835), ('inside', 5712), ('everything', 5578), ('alone', 5576), ('face', 5439), ('dont', 5207), ('ever', 5099), ('something', 5035), ('stay', 4976), ('bridge', 4824), ('walk', 4793), ('god', 4713), ('soul', 4707), ('another', 4680), ('stand', 4655), ('little', 4652), ('place', 4631), ('pre', 4469), ('change', 4459), ('fire', 4388), ('word', 4361), ('believe', 4343), ('cause', 4338), ('stop', 4322), ('last', 4308), ('dead', 4272), ('fight', 4267), ('much', 4258), ('girl', 4181), ('friend', 4167), ('even', 4163), ('cry', 4052), ('start', 4029), ('hey', 3989), ('watch', 3975), ('new', 3939), ('pain', 3935), ('blood', 3926), ('show', 3919), ('mean', 3916), ('hard', 3840), ('bring', 3814), ('sky', 3811), ('la', 3810), ('sun', 3791), ('high', 3682), ('free', 3674), ('close', 3592), ('outro', 3591), ('far', 3555), ('tonight', 3545), ('play', 3528), ('ooh', 3518), ('old', 3503), ('sing', 3498), ('death', 3492), ('care', 3469), ('without', 3462), ('really', 3458), ('tear', 3425), ('kill', 3410), ('dark', 3407), ('fear', 3405), ('dance', 3394), ('hope', 3392), ('move', 3373), ('sleep', 3347), ('name', 3347), ('put', 3282), ('wrong', 3270), ('please', 3269), ('star', 3256), ('black', 3241), ('people', 3215), ('cold', 3214), ('bad', 3208), ('forget', 3185), ('maybe', 3058), ('youre', 3058), ('use', 3054), ('enough', 3029), ('hide', 2986), ('talk', 2983), ('line', 2976), ('hate', 2960), ('rise', 2951), ('song', 2920), ('seem', 2918), ('open', 2916), ('do', 2916), ('year', 2909), ('hell', 2908), ('wish', 2849), ('side', 2829), ('deep', 2795), ('save', 2788), ('ah', 2784), ('mine', 2782), ('help', 2770), ('forever', 2753), ('cant', 2733), ('behind', 2692), ('must', 2629), ('remember', 2613), ('alive', 2604), ('someone', 2572), ('grow', 2561), ('two', 2559), ('body', 2548), ('ill', 2540), ('sound', 2530), ('grind', 2490), ('blue', 2488), ('truth', 2487), ('door', 2421), ('wake', 2366), ('rain', 2346), ('wall', 2333), ('set', 2316), ('fade', 2308), ('rock', 2295), ('real', 2288), ('best', 2266), ('true', 2251), ('waste', 2244), ('work', 2233), ('ask', 2204), ('fly', 2199), ('drink', 2197), ('boy', 2190), ('bear', 2166), ('yes', 2149), ('become', 2149), ('speak', 2144), ('breathe', 2143), ('late', 2125), ('war', 2115), ('miss', 2112), ('scream', 2109), ('smile', 2107), ('might', 2099), ('meet', 2087), ('big', 2058), ('wind', 2055), ('roll', 2053), ('alright', 2040), ('many', 2027), ('begin', 2027), ('voice', 2025), ('ive', 2019), ('follow', 2004), ('past', 2001), ('catch', 1987), ('lay', 1972), ('control', 1961), ('beat', 1950), ('first', 1947), ('fine', 1925), ('child', 1918), ('else', 1901), ('street', 1899), ('cut', 1893), ('learn', 1891), ('hurt', 1890), ('reason', 1885), ('everyone', 1885), ('today',  ...
#
# Genre: rb
# Top 3000: [('get', 22489), ('know', 19443), ('love', 19056), ('yeah', 15446), ('like', 12973), ('oh', 12791), ('baby', 12353), ('na', 12030), ('go', 11382), ('say', 9779), ('feel', 8685), ('want', 8370), ('make', 8283), ('let', 7927), ('girl', 7735), ('time', 7661), ('wan', 7477), ('come', 7160), ('need', 6846), ('see', 6777), ('tell', 6385), ('take', 6239), ('one', 6108), ('good', 5713), ('never', 5670), ('think', 5584), ('way', 5545), ('im', 5540), ('give', 5195), ('back', 4854), ('shall', 4814), ('right', 4740), ('gon', 4727), ('ooh', 4601), ('dont', 4464), ('u', 4349), ('would', 4135), ('keep', 3947), ('could', 3780), ('thing', 3651), ('day', 3622), ('night', 3567), ('leave', 3553), ('life', 3536), ('look', 3463), ('heart', 3234), ('mind', 3202), ('fuck', 3047), ('cause', 2950), ('call', 2910), ('try', 2708), ('hold', 2673), ('away', 2600), ('man', 2583), ('still', 2569), ('really', 2477), ('find', 2470), ('stay', 2379), ('hey', 2350), ('always', 2320), ('put', 2297), ('pre', 2282), ('ya', 2250), ('around', 2240), ('show', 2205), ('even', 2194), ('shit', 2168), ('break', 2167), ('lose', 2153), ('every', 2108), ('hook', 2076), ('play', 2059), ('wait', 2042), ('ever', 2024), ('real', 2022), ('talk', 2009), ('nigga', 1999), ('eye', 1982), ('long', 1946), ('fall', 1922), ('live', 1910), ('something', 1910), ('bridge', 1906), ('bad', 1889), ('world', 1860), ('everything', 1853), ('much', 1802), ('la', 1782), ('run', 1779), ('hear', 1775), ('nothing', 1756), ('body', 1711), ('little', 1677), ('cant', 1630), ('ah', 1625), ('bout', 1625), ('outro', 1622), ('boy', 1604), ('tonight', 1586), ('alone', 1584), ('stop', 1584), ('lie', 1584), ('high', 1568), ('hard', 1557), ('turn', 1550), ('change', 1539), ('please', 1534), ('dream', 1522), ('hand', 1491), ('bitch', 1481), ('move', 1480), ('youre', 1463), ('mean', 1460), ('light', 1459), ('home', 1439), ('new', 1438), ('miss', 1437), ('friend', 1430), ('mine', 1428), ('cry', 1419), ('tryna', 1415), ('uh', 1411), ('close', 1389), ('well', 1362), ('aint', 1343), ('hit', 1335), ('intro', 1321), ('believe', 1311), ('nobody', 1299), ('god', 1296), ('name', 1296), ('side', 1292), ('care', 1288), ('face', 1283), ('babe', 1282), ('crazy', 1276), ('head', 1271), ('work', 1266), ('money', 1255), ('do', 1242), ('wrong', 1239), ('ill', 1211), ('use', 1203), ('walk', 1191), ('start', 1180), ('end', 1171), ('game', 1148), ('ride', 1141), ('die', 1138), ('inside', 1127), ('em', 1112), ('dance', 1108), ('last', 1103), ('place', 1098), ('watch', 1098), ('yes', 1098), ('best', 1097), ('bring', 1093), ('pain', 1080), ('another', 1075), ('maybe', 1074), ('x', 1070), ('yea', 1070), ('enough', 1065), ('might', 1063), ('soul', 1057), ('true', 1056), ('sweet', 1044), ('people', 1034), ('without', 1016), ('two', 1015), ('wish', 1008), ('kiss', 987), ('hurt', 984), ('someone', 982), ('deep', 982), ('help', 958), ('thats', 952), ('hope', 950), ('forever', 941), ('free', 937), ('word', 920), ('alright', 915), ('touch', 910), ('round', 903), ('fly', 899), ('da', 890), ('damn', 878), ('ask', 873), ('catch', 871), ('pull', 866), ('ready', 856), ('low', 853), ('sing', 853), ('slow', 848), ('fine', 843), ('song', 839), ('together', 838), ('else', 835), ('phone', 825), ('many', 825), ('late', 822), ('roll', 817), ('forget', 810), ('woah', 808), ('star', 805), ('promise', 799), ('stand', 786), ('fight', 783), ('lord', 778), ('big', 776), ('remember', 776), ('lay', 775), ('listen', 771), ('meet', 766), ('lonely', 765), ('yo', 765), ('cold', 758), ('sometimes', 757), ('first', 756), ('smile', 751), ('trust', 751), ('sleep', 749), ('somebody', 746), ('guess', 745), ('hate', 743), ('far', 741), ('though', 731), ('beat', 728), ('cool', 723), ('drink', 722), ('fire', 719), ('cuz', 719), ('seem', 711), ('sun', 707), ('old', 701), ('sure', 698), ('understand', 691), ('ive', 690), ('tear', 686), ('till', 682), ('act', 673), ('ama', 673), ('til', 672), ('blue', 670), ('shawty', 670), ('woman', 666), ('sky', 665), ('matter', 664),  ...
#
# Genre: misc
# Top 3000: [('say', 22763), ('one', 17748), ('go', 16891), ('know', 14921), ('would', 14871), ('like', 14632), ('make', 14041), ('come', 14032), ('get', 12717), ('see', 11507), ('time', 10985), ('take', 10398), ('think', 10363), ('man', 9646), ('good', 9473), ('look', 9174), ('could', 8971), ('u', 8669), ('shall', 8641), ('give', 8261), ('day', 7879), ('well', 7190), ('thing', 6781), ('love', 6737), ('tell', 6725), ('way', 6590), ('mr', 6496), ('never', 6420), ('people', 6291), ('back', 6260), ('even', 6259), ('great', 6211), ('upon', 6158), ('find', 6136), ('hand', 6130), ('may', 6102), ('little', 6097), ('want', 6039), ('long', 5938), ('first', 5848), ('right', 5843), ('leave', 5823), ('let', 5618), ('life', 5611), ('must', 5509), ('two', 5469), ('much', 5136), ('eye', 5061), ('work', 5029), ('year', 4963), ('hear', 4950), ('old', 4910), ('still', 4817), ('god', 4778), ('call', 4747), ('mean', 4613), ('every', 4558), ('place', 4533), ('world', 4516), ('away', 4438), ('men', 4347), ('new', 4323), ('live', 4304), ('house', 4294), ('use', 4292), ('without', 4191), ('turn', 4120), ('oh', 4117), ('many', 4100), ('feel', 4085), ('face', 4071), ('head', 4053), ('night', 3974), ('might', 3966), ('word', 3946), ('stand', 3910), ('keep', 3899), ('yet', 3848), ('woman', 3836), ('state', 3827), ('nothing', 3807), ('seem', 3757), ('put', 3744), ('ask', 3695), ('need', 3645), ('speak', 3641), ('last', 3619), ('light', 3605), ('also', 3591), ('though', 3589), ('mind', 3564), ('begin', 3558), ('another', 3517), ('name', 3492), ('always', 3450), ('hold', 3435), ('heart', 3384), ('father', 3358), ('bring', 3337), ('part', 3328), ('ever', 3260), ('try', 3222), ('something', 3216), ('end', 3203), ('child', 3177), ('thou', 3154), ('friend', 3137), ('show', 3135), ('become', 3117), ('run', 3046), ('sit', 3025), ('talk', 2989), ('young', 2976), ('high', 2972), ('room', 2868), ('open', 2841), ('far', 2795), ('door', 2794), ('three', 2792), ('saw', 2770), ('king', 2749), ('home', 2749), ('lord', 2704), ('really', 2615), ('pas', 2610), ('believe', 2603), ('follow', 2596), ('sir', 2592), ('thy', 2578), ('walk', 2577), ('power', 2541), ('mother', 2530), ('write', 2528), ('cry', 2518), ('do', 2517), ('side', 2517), ('girl', 2495), ('yes', 2486), ('set', 2485), ('break', 2445), ('son', 2443), ('understand', 2439), ('body', 2438), ('white', 2399), ('change', 2398), ('black', 2387), ('play', 2382), ('lose', 2378), ('around', 2345), ('cause', 2339), ('na', 2326), ('help', 2323), ('fall', 2314), ('water', 2304), ('money', 2301), ('law', 2275), ('form', 2257), ('die', 2248), ('point', 2245), ('start', 2237), ('move', 2236), ('best', 2226), ('moment', 2223), ('matter', 2223), ('yeah', 2222), ('reason', 2222), ('arm', 2221), ('im', 2204), ('kind', 2200), ('meet', 2197), ('since', 2192), ('boy', 2188), ('thee', 2175), ('order', 2173), ('whole', 2163), ('idea', 2163), ('case', 2156), ('bad', 2156), ('thus', 2156), ('soul', 2155), ('stop', 2149), ('death', 2141), ('answer', 2140), ('close', 2127), ('wait', 2118), ('return', 2116), ('person', 2114), ('foot', 2105), ('land', 2096), ('country', 2079), ('enough', 2078), ('grow', 2073), ('bear', 2067), ('late', 2059), ('voice', 2055), ('dream', 2052), ('rise', 2047), ('together', 2038), ('lay', 2035), ('dont', 2021), ('lady', 2013), ('wish', 2002), ('question', 1997), ('lie', 1996), ('fire', 1984), ('true', 1980), ('read', 1972), ('hour', 1970), ('anything', 1969), ('full', 1947), ('fact', 1931), ('watch', 1931), ('miss', 1918), ('among', 1912), ('present', 1900), ('happen', 1900), ('next', 1899), ('nature', 1898), ('care', 1895), ('alone', 1874), ('le', 1873), ('send', 1853), ('everything', 1853), ('earth', 1840), ('round', 1832), ('course', 1824), ('human', 1824), ('however', 1801), ('appear', 1795), ('sound', 1777), ('act', 1771), ('lead', 1769), ('half', 1768), ('big', 1767), ('remember', 1764), ('soon', 1762), ('within', 1751), ('kill', 1747), ('felt', 1743), ('interest', 1739), ('whose', 1728), ('war', 1724), ('su ...
#
# Genre: country
# Top 3000: [('get', 8083), ('love', 5374), ('know', 5271), ('go', 5065), ('like', 4236), ('say', 3391), ('shall', 3281), ('time', 3235), ('oh', 3139), ('one', 3118), ('na', 3099), ('come', 3014), ('would', 2805), ('make', 2794), ('take', 2709), ('back', 2443), ('way', 2410), ('see', 2401), ('never', 2331), ('good', 2328), ('let', 2287), ('yeah', 2207), ('think', 2029), ('heart', 2007), ('day', 2005), ('want', 1988), ('baby', 1914), ('tell', 1908), ('gon', 1900), ('night', 1887), ('little', 1848), ('leave', 1832), ('well', 1803), ('could', 1754), ('man', 1631), ('long', 1608), ('feel', 1582), ('away', 1566), ('look', 1565), ('home', 1561), ('old', 1558), ('thing', 1497), ('right', 1465), ('need', 1438), ('give', 1385), ('girl', 1375), ('keep', 1356), ('u', 1329), ('every', 1326), ('find', 1320), ('still', 1269), ('life', 1234), ('song', 1210), ('nerve', 1198), ('hold', 1157), ('around', 1150), ('break', 1114), ('ever', 1085), ('eye', 1071), ('call', 1054), ('run', 1038), ('hand', 1027), ('light', 1027), ('live', 1021), ('wan', 1015), ('world', 1000), ('turn', 965), ('hear', 958), ('always', 925), ('walk', 917), ('try', 915), ('mind', 897), ('boy', 890), ('lose', 880), ('blue', 870), ('fall', 868), ('town', 856), ('sing', 825), ('dream', 796), ('road', 784), ('big', 776), ('cry', 772), ('hard', 769), ('drink', 755), ('friend', 746), ('stay', 736), ('head', 728), ('lord', 717), ('bridge', 716), ('start', 708), ('even', 699), ('nothing', 693), ('another', 692), ('tonight', 671), ('cause', 667), ('wait', 654), ('alone', 652), ('change', 650), ('believe', 646), ('place', 640), ('god', 638), ('new', 637), ('last', 637), ('im', 635), ('two', 635), ('ooh', 630), ('everything', 628), ('something', 618), ('country', 616), ('use', 614), ('play', 614), ('end', 607), ('sweet', 607), ('do', 604), ('put', 601), ('much', 600), ('wish', 589), ('name', 586), ('woman', 579), ('wrong', 578), ('kiss', 576), ('mine', 576), ('line', 566), ('rain', 566), ('stand', 563), ('outro', 560), ('high', 558), ('die', 558), ('roll', 558), ('year', 554), ('tear', 550), ('mean', 545), ('bad', 543), ('hey', 541), ('sun', 540), ('work', 539), ('fire', 535), ('cold', 528), ('lay', 526), ('might', 521), ('miss', 519), ('bring', 516), ('wind', 510), ('close', 510), ('star', 507), ('stop', 506), ('talk', 500), ('word', 497), ('face', 494), ('show', 494), ('soul', 488), ('lie', 488), ('people', 486), ('side', 485), ('door', 484), ('really', 483), ('meet', 474), ('crazy', 465), ('fly', 464), ('smile', 463), ('enough', 463), ('dance', 460), ('hell', 457), ('em', 456), ('move', 455), ('maybe', 455), ('free', 454), ('dont', 453), ('drive', 446), ('ride', 442), ('true', 442), ('sit', 441), ('best', 439), ('sky', 431), ('grow', 431), ('wonder', 430), ('without', 426), ('burn', 426), ('sometimes', 425), ('sure', 420), ('far', 417), ('morning', 415), ('along', 415), ('first', 414), ('red', 406), ('help', 406), ('hope', 406), ('til', 400), ('memory', 398), ('someone', 398), ('guess', 397), ('watch', 397), ('care', 397), ('yes', 395), ('round', 394), ('pretty', 391), ('may', 390), ('lonely', 389), ('water', 388), ('arm', 385), ('ask', 385), ('hurt', 384), ('remember', 384), ('grind', 382), ('strong', 381), ('daddy', 381), ('forget', 380), ('fight', 378), ('nobody', 378), ('seem', 378), ('mama', 376), ('deep', 373), ('river', 369), ('pre', 366), ('saw', 364), ('please', 360), ('rock', 360), ('rise', 360), ('must', 359), ('dark', 359), ('ill', 357), ('white', 356), ('late', 353), ('heaven', 353), ('goodbye', 349), ('honey', 347), ('bear', 346), ('train', 344), ('behind', 342), ('catch', 338), ('bout', 338), ('together', 337), ('black', 337), ('sleep', 337), ('forever', 335), ('till', 335), ('real', 335), ('else', 334), ('everybody', 333), ('since', 330), ('happy', 329), ('fine', 328), ('many', 326), ('today', 326), ('foot', 321), ('tree', 317), ('anything', 316), ('matter', 313), ('open', 312), ('inside', 311), ('lot', 310), ('fool', 309), ('pull', 309), ('kind', 308), ('young', 306 ...

# %% [markdown]
# Before getting our vocabulary based on the loga ratio analysis made later on this notebook, we must define the distribution of words present in the vocabulary:

# %%
# each weight is based on the percetange of rows per tag in the whole data
distribution = {
    'pop': int(n * (0.413008)),
    'rap': int(n * (0.285879)),
    'rock': int(n * (0.187692)),
    'rb': int(n * (0.045960)),
    'misc': int(n * (0.041781)),
    'country': int(n * (0.025681))
}

# %% [markdown]
# In the next cell we get a dictionary called `log_values` in which it has a length of `n` and has the most important words for each tag.

# %%
log_values = log_ratio_analysis(top_words,
                                tags,
                                total_words_tag,
                                total_words,
                                distribution,
                                data,
                                label = 'tag')

# %% [markdown]
# Lets have a quick check on how many words is there for each tag.
# The total number of words will not match the given `n` given the percentages in the `distribution` object.

# %%
sum = 0
for genre in data.tag.value_counts().keys():
    print(f"{genre}: {len(log_values[genre])} \n")
    sum += len(log_values[genre])

print(sum)
# Out:
# pop: 1239
#
# rap: 857
#
# rock: 563
#
# rb: 137
#
# misc: 125
#
# country: 77
#
# 2998

# %% [markdown]
# Before letting this be our final vocabulary to fit into our vectorizer, lets see if there are any words that are considered important in too many tags.

# %%
common_keys = find_common_keys(log_values)
common_keys
# Out:
# {'shatter': ['pop', 'rock'],
#  'cling': ['pop', 'rock'],
#  'cruel': ['pop', 'rock'],
#  'farewell': ['pop', 'rock'],
#  'misery': ['pop', 'rock'],
#  'toll': ['pop', 'rock'],
#  'masquerade': ['pop', 'rock'],
#  'sorrow': ['pop', 'rock'],
#  'nowhere': ['pop', 'rock'],
#  'reveal': ['pop', 'rock'],
#  'within': ['pop', 'rock'],
#  'judgement': ['pop', 'rock'],
#  'instrumental': ['pop', 'rock'],
#  'despair': ['pop', 'rock'],
#  'crumble': ['pop', 'rock'],
#  'spiral': ['pop', 'rock'],
#  'burden': ['pop', 'rock'],
#  'midnight': ['pop', 'rock'],
#  'darkness': ['pop', 'rock'],
#  'wind': ['pop', 'rock'],
#  'someday': ['pop', 'rock'],
#  'unfold': ['pop', 'rock'],
#  'guitar': ['pop', 'rock'],
#  'awaken': ['pop', 'rock'],
#  'sleepless': ['pop', 'rock'],
#  'silence': ['pop', 'rock'],
#  'overwhelm': ['pop', 'rock'],
#  'everyone': ['pop', 'rock'],
#  'poison': ['pop', 'rock'],
#  'mold': ['pop', 'rock'],
#  'emptiness': ['pop', 'rock'],
#  'spell': ['pop', 'rock'],
#  'shallow': ['pop', 'rock'],
#  'everythings': ['pop', 'rock'],
#  'halfway': ['pop', 'rock'],
#  'fog': ['pop', 'rock'],
#  'nightmare': ['pop', 'rock'],
#  'eternally': ['pop', 'rock'],
#  'forsake': ['pop', 'rock'],
#  'sky': ['pop', 'rock'],
#  'dust': ['pop', 'rock'],
#  'obey': ['pop', 'rock'],
#  'desperate': ['pop', 'rock'],
#  'sin': ['pop', 'rock'],
#  'slowly': ['pop', 'rock'],
#  'cure': ['pop', 'rock'],
#  'undo': ['pop', 'rock'],
#  'robot': ['pop', 'rock'],
#  'reel': ['pop', 'rock'],
#  'drown': ['pop', 'rock'],
#  'beneath': ['pop', 'rock'],
#  'tide': ['pop', 'rock'],
#  'sew': ['pop', 'rock'],
#  'underneath': ['pop', 'rock'],
#  'earth': ['pop', 'rock'],
#  'collide': ['pop', 'rock'],
#  'vein': ['pop', 'rock'],
#  'die': ['pop', 'rock'],
#  'aa': ['pop', 'rock'],
#  'sun': ['pop', 'rock'],
#  'forgiveness': ['pop', 'rock'],
#  'thirst': ['pop', 'rock'],
#  'drag': ['pop', 'rock'],
#  'celebration': ['pop', 'rock'],
#  'away': ['pop', 'rock'],
#  'survive': ['pop', 'rock'],
#  'dolla': ['rap', 'rb'],
#  'fragile': ['pop', 'rock'],
#  'cradle': ['pop', 'rock'],
#  'parade': ['pop', 'rock'],
#  'photograph': ['pop', 'rock'],
#  'refrain': ['pop', 'rock'],
#  'echo': ['pop', 'rock'],
#  'razor': ['pop', 'rock'],
#  'bridge': ['pop', 'rock'],
#  'obsession': ['pop', 'rock'],
#  'linger': ['pop', 'rock'],
#  'sand': ['pop', 'rock'],
#  'await': ['pop', 'rock'],
#  'soak': ['pop', 'rock'],
#  'embrace': ['pop', 'rock'],
#  'graveyard': ['pop', 'rock'],
#  'pierce': ['pop', 'rock'],
#  'neon': ['pop', 'rock'],
#  'puppet': ['pop', 'rock'],
#  'distant': ['pop', 'rock'],
#  'fate': ['pop', 'rock'],
#  'horizon': ['pop', 'rock'],
#  'nana': ['pop', 'rb'],
#  'salvation': ['pop', 'rock'],
#  'fade': ['pop', 'rock'],
#  'bone': ['pop', 'rock'],
#  'breathe': ['pop', 'rock'],
#  'disaster': ['pop', 'rock'],
#  'anchor': ['pop', 'rock'],
#  'endlessly': ['pop', 'rock'],
#  'kingdom': ['pop', 'rock'],
#  'guilt': ['pop', 'rock'],
#  'flame': ['pop', 'rock'],
#  'justify': ['pop', 'rock'],
#  'northern': ['pop', 'rock'],
#  'chemical': ['pop', 'rock'],
#  'trace': ['pop', 'rock'],
#  'apart': ['pop', 'rock'],
#  'suffocate': ['pop', 'rock'],
#  'howl': ['pop', 'rock'],
#  'unknown': ['pop', 'rock'],
#  'eternal': ['pop', 'rock'],
#  'bittersweet': ['pop', 'rock'],
#  'carve': ['pop', 'rock'],
#  'lust': ['pop', 'rock'],
#  'goodnight': ['pop', 'rock'],
#  'thunder': ['pop', 'rock'],
#  'fingertip': ['pop', 'rock'],
#  'dawn': ['pop', 'rock'],
#  'demise': ['pop', 'rock'],
#  'wall': ['pop', 'rock'],
#  'haunt': ['pop', 'rock'],
#  'dark': ['pop', 'rock'],
#  'bury': ['pop', 'rock'],
#  'rust': ['pop', 'rock'],
#  'denial': ['pop', 'rock'],
#  'awake': ['pop', 'rock'],
#  'pulse': ['pop', 'rock'],
#  'fear': ['pop', 'rock'],
#  'witch': ['pop', 'rock'],
#  'silently': ['pop', 'rock'],
#  'erase': ['pop', 'rock'],
#  'onto': ['pop', 'rock'],
#  'sha': ['pop', 'rock'],
#  'resist': ['pop', 'rock'],
#  'teenage': ['pop', 'rock'],
#  'glimpse': ['pop', 'rock'],
#  'caress': ['pop', 'rock'],
#  'reflection': ['pop', 'rock'],
#  'disguise': ['pop', 'rock'],
#  'drift': ['pop', 'rock'],
#  'mountain': ['pop', 'rock'],
#  'fire': ['pop', 'rock'],
#  'ignite': ['pop', 'rock'],
#  'illusion': ['pop', 'rock'],
#  'inside': ['pop', 'rock'],
#  'unwind': ['pop', 'rock'],
#  'hail': ['pop', 'rock'],
#  'breakdown': ['pop', 'rock'],
#  'beware': ['pop', 'rock'],
#  'redemption': ['pop', 'rock'],
#  'guide': ['pop', 'rock'],
#  'reign': ['pop', 'rock'],
#  'weakness': ['pop', 'rock'],
#  'blind': ['pop', 'rock'],
#  'restless': ['pop', 'rock'],
#  'hide': ['pop', 'rock'],
#  'skin': ['pop', 'rock'],
#  'dissolve': ['pop', 'rock'],
#  'dusk': ['pop', 'rock'],
#  'disappear': ['pop', 'rock'],
#  'sadness': ['pop', 'rock'],
#  'rise': ['pop', 'rock'],
#  'empty': ['pop', 'rock'],
#  'getaway': ['pop', 'rock'],
#  'siren': ['pop', 'rock'],
#  'shadow': ['pop', 'rock'],
#  'lightning': ['pop', 'rock'],
#  'edge': ['pop', 'rock'],
#  'thorn': ['pop', 'rock'],
#  'astray': ['pop', 'rock'],
#  'bitter': ['pop', 'rock'],
#  'sail': ['pop', 'rock'],
#  'machine': ['pop', 'rock'],
#  'loneliness': ['pop', 'rock'],
#  'weve': ['pop', 'rock'],
#  'escape': ['pop', 'rock'],
#  'yearn': ['pop', 'rock'],
#  'telephone': ['pop', 'rock'],
#  'tangle': ['pop', 'rock'],
#  'ache': ['pop', 'rock'],
#  'scream': ['pop', 'rock'],
#  'sow': ['pop', 'rock'],
#  'forevermore': ['pop', 'rock'],
#  'behind': ['pop', 'rock'],
#  'hole': ['pop', 'rock'],
#  'explode': ['pop', 'rock'],
#  'starlight': ['pop', 'rock'],
#  'revelation': ['pop', 'rock'],
#  'alive': ['pop', 'rock'],
#  'eternity': ['pop', 'rock'],
#  'storm': ['pop', 'rock'],
#  'liar': ['pop', 'rock'],
#  'doo': ['pop', 'rock'],
#  'breath': ['pop', 'rock'],
#  'end': ['pop', 'rock'],
#  'terrify': ['pop', 'rock'],
#  'beg': ['pop', 'rock'],
#  'whisper': ['pop', 'rock'],
#  'paralyze': ['pop', 'rock'],
#  'stare': ['pop', 'rock'],
#  'shiver': ['pop', 'rock'],
#  'burn': ['pop', 'rock'],
#  'tremble': ['pop', 'rock'],
#  'anymore': ['pop', 'rock'],
#  'satellite': ['pop', 'rock'],
#  'greed': ['pop', 'rock'],
#  'ninja': ['rap', 'rock'],
#  'raven': ['pop', 'rock'],
#  'fuel': ['pop', 'rock'],
#  'wander': ['pop', 'rock'],
#  'runaway': ['pop', 'rock'],
#  'wound': ['pop', 'rock'],
#  'seam': ['pop', 'rock'],
#  'cleanse': ['pop', 'rock'],
#  'sink': ['pop', 'rock'],
#  'rescue': ['pop', 'rock'],
#  'sea': ['pop', 'rock'],
#  'darken': ['pop', 'rock'],
#  'roam': ['pop', 'rock'],
#  'surrender': ['pop', 'rock'],
#  'insanity': ['pop', 'rock'],
#  'saviour': ['pop', 'rock'],
#  'brave': ['pop', 'rock'],
#  'crawl': ['pop', 'rock'],
#  'betray': ['pop', 'rock'],
#  'youve': ['pop', 'rock'],
#  'veil': ['pop', 'rock'],
#  'innocence': ['pop', 'rock'],
#  'chaos': ['pop', 'rock'],
#  'bind': ['pop', 'rock'],
#  'endless': ['pop', 'rock'],
#  'crucify': ['pop', 'rock'],
#  'warmth': ['pop', 'rock'],
#  'bleed': ['pop', 'rock'],
#  'final': ['pop', 'rock'],
#  'roar': ['pop', 'rock'],
#  'regret': ['pop', 'rock'],
#  'helpless': ['pop', 'rock'],
#  'beyond': ['pop', 'rock']}

# %%
key_frequencies = {key: len(locations) for key, locations in common_keys.items()}
sorted_key_frequencies = dict(sorted(key_frequencies.items(), key=lambda item: item[1], reverse=True))

# %% [markdown]
# As we can see, there are only words considered important in either 1 or 2 tags, we will allow this words to be in our final vocabulary.

# %%
sorted_key_frequencies
# Out:
# {'shatter': 2,
#  'cling': 2,
#  'cruel': 2,
#  'farewell': 2,
#  'misery': 2,
#  'toll': 2,
#  'masquerade': 2,
#  'sorrow': 2,
#  'nowhere': 2,
#  'reveal': 2,
#  'within': 2,
#  'judgement': 2,
#  'instrumental': 2,
#  'despair': 2,
#  'crumble': 2,
#  'spiral': 2,
#  'burden': 2,
#  'midnight': 2,
#  'darkness': 2,
#  'wind': 2,
#  'someday': 2,
#  'unfold': 2,
#  'guitar': 2,
#  'awaken': 2,
#  'sleepless': 2,
#  'silence': 2,
#  'overwhelm': 2,
#  'everyone': 2,
#  'poison': 2,
#  'mold': 2,
#  'emptiness': 2,
#  'spell': 2,
#  'shallow': 2,
#  'everythings': 2,
#  'halfway': 2,
#  'fog': 2,
#  'nightmare': 2,
#  'eternally': 2,
#  'forsake': 2,
#  'sky': 2,
#  'dust': 2,
#  'obey': 2,
#  'desperate': 2,
#  'sin': 2,
#  'slowly': 2,
#  'cure': 2,
#  'undo': 2,
#  'robot': 2,
#  'reel': 2,
#  'drown': 2,
#  'beneath': 2,
#  'tide': 2,
#  'sew': 2,
#  'underneath': 2,
#  'earth': 2,
#  'collide': 2,
#  'vein': 2,
#  'die': 2,
#  'aa': 2,
#  'sun': 2,
#  'forgiveness': 2,
#  'thirst': 2,
#  'drag': 2,
#  'celebration': 2,
#  'away': 2,
#  'survive': 2,
#  'dolla': 2,
#  'fragile': 2,
#  'cradle': 2,
#  'parade': 2,
#  'photograph': 2,
#  'refrain': 2,
#  'echo': 2,
#  'razor': 2,
#  'bridge': 2,
#  'obsession': 2,
#  'linger': 2,
#  'sand': 2,
#  'await': 2,
#  'soak': 2,
#  'embrace': 2,
#  'graveyard': 2,
#  'pierce': 2,
#  'neon': 2,
#  'puppet': 2,
#  'distant': 2,
#  'fate': 2,
#  'horizon': 2,
#  'nana': 2,
#  'salvation': 2,
#  'fade': 2,
#  'bone': 2,
#  'breathe': 2,
#  'disaster': 2,
#  'anchor': 2,
#  'endlessly': 2,
#  'kingdom': 2,
#  'guilt': 2,
#  'flame': 2,
#  'justify': 2,
#  'northern': 2,
#  'chemical': 2,
#  'trace': 2,
#  'apart': 2,
#  'suffocate': 2,
#  'howl': 2,
#  'unknown': 2,
#  'eternal': 2,
#  'bittersweet': 2,
#  'carve': 2,
#  'lust': 2,
#  'goodnight': 2,
#  'thunder': 2,
#  'fingertip': 2,
#  'dawn': 2,
#  'demise': 2,
#  'wall': 2,
#  'haunt': 2,
#  'dark': 2,
#  'bury': 2,
#  'rust': 2,
#  'denial': 2,
#  'awake': 2,
#  'pulse': 2,
#  'fear': 2,
#  'witch': 2,
#  'silently': 2,
#  'erase': 2,
#  'onto': 2,
#  'sha': 2,
#  'resist': 2,
#  'teenage': 2,
#  'glimpse': 2,
#  'caress': 2,
#  'reflection': 2,
#  'disguise': 2,
#  'drift': 2,
#  'mountain': 2,
#  'fire': 2,
#  'ignite': 2,
#  'illusion': 2,
#  'inside': 2,
#  'unwind': 2,
#  'hail': 2,
#  'breakdown': 2,
#  'beware': 2,
#  'redemption': 2,
#  'guide': 2,
#  'reign': 2,
#  'weakness': 2,
#  'blind': 2,
#  'restless': 2,
#  'hide': 2,
#  'skin': 2,
#  'dissolve': 2,
#  'dusk': 2,
#  'disappear': 2,
#  'sadness': 2,
#  'rise': 2,
#  'empty': 2,
#  'getaway': 2,
#  'siren': 2,
#  'shadow': 2,
#  'lightning': 2,
#  'edge': 2,
#  'thorn': 2,
#  'astray': 2,
#  'bitter': 2,
#  'sail': 2,
#  'machine': 2,
#  'loneliness': 2,
#  'weve': 2,
#  'escape': 2,
#  'yearn': 2,
#  'telephone': 2,
#  'tangle': 2,
#  'ache': 2,
#  'scream': 2,
#  'sow': 2,
#  'forevermore': 2,
#  'behind': 2,
#  'hole': 2,
#  'explode': 2,
#  'starlight': 2,
#  'revelation': 2,
#  'alive': 2,
#  'eternity': 2,
#  'storm': 2,
#  'liar': 2,
#  'doo': 2,
#  'breath': 2,
#  'end': 2,
#  'terrify': 2,
#  'beg': 2,
#  'whisper': 2,
#  'paralyze': 2,
#  'stare': 2,
#  'shiver': 2,
#  'burn': 2,
#  'tremble': 2,
#  'anymore': 2,
#  'satellite': 2,
#  'greed': 2,
#  'ninja': 2,
#  'raven': 2,
#  'fuel': 2,
#  'wander': 2,
#  'runaway': 2,
#  'wound': 2,
#  'seam': 2,
#  'cleanse': 2,
#  'sink': 2,
#  'rescue': 2,
#  'sea': 2,
#  'darken': 2,
#  'roam': 2,
#  'surrender': 2,
#  'insanity': 2,
#  'saviour': 2,
#  'brave': 2,
#  'crawl': 2,
#  'betray': 2,
#  'youve': 2,
#  'veil': 2,
#  'innocence': 2,
#  'chaos': 2,
#  'bind': 2,
#  'endless': 2,
#  'crucify': 2,
#  'warmth': 2,
#  'bleed': 2,
#  'final': 2,
#  'roar': 2,
#  'regret': 2,
#  'helpless': 2,
#  'beyond': 2}

# %% [markdown]
# Now, lets save our vocabulary in a different file named `vocabulary` which will consist in a file filled with a list (`best_words`) that has the words that better represent our tags.

# %%
best_words = []
for tag in log_values:
    for word in log_values[tag]:
        best_words.append(word[0])

print(best_words)
len(set(best_words))
# Out:
# ['chee', 'oya', 'sleigh', 'woh', 'bruk', 'ev', 'rosie', 'waan', 'hallelujah', 'disco', 'ariana', 'woof', 'starlight', 'grande', 'aaah', 'amin', 'aah', 'ooooo', 'unkind', 'ooooh', 'bwoy', 'mistletoe', 'ry', 'oo', 'merry', 'christmas', 'darlin', 'heartbeat', 'fairytale', 'starry', 'gal', 'romance', 'claus', 'ly', 'heartbreaker', 'newborn', 'jingle', 'noel', 'la', 'whatcha', 'seh', 'eh', 'lullaby', 'fabulous', 'moonlight', 'lover', 'goodbye', 'pum', 'jo', 'wo', 'bawl', 'darling', 'raindrop', 'silhouette', 'dum', 'sunshine', 'jah', 'adore', 'overflow', 'sushi', 'oh', 'eternally', 'wonderland', 'fi', 'gyal', 'paradise', 'ba', 'someday', 'jive', 'goodnight', 'rhythm', 'ee', 'fingertip', 'tonight', 'loneliness', 'bittersweet', 'alibi', 'heartache', 'somehow', 'spooky', 'gypsy', 'sunrise', 'pre', 'overload', 'ooo', 'symphony', 'stormy', 'forevermore', 'joyful', 'oooh', 'twilight', 'surrender', 'dance', 'harmony', 'madonna', 'tu', 'lonesome', 'rainbow', 'hoo', 'caroline', 'sing', 'wah', 'dreamer', 'everlasting', 'beautiful', 'lovin', 'mu', 'photograph', 'sunlight', 'oooo', 'wey', 'sweetheart', 'endlessly', 'wherever', 'sally', 'softly', 'sexy', 'teardrop', 'whine', 'dancer', 'inna', 'undo', 'anymore', 'hometown', 'miracle', 'sail', 'melody', 'hum', 'forever', 'tomorrow', 'velvet', 'anywhere', 'oooooh', 'dada', 'kiss', 'shelter', 'tumble', 'glory', 'ooh', 'ole', 'heart', 'belong', 'thrill', 'angel', 'beggin', 'love', 'someone', 'lonely', 'pon', 'fantasy', 'fragile', 'mend', 'daydream', 'rainy', 'yesterday', 'dey', 'anytime', 'ahhh', 'santa', 'nuh', 'ow', 'restless', 'sweet', 'omo', 'collide', 'fe', 'choo', 'mystery', 'balloon', 'willow', 'butterfly', 'suitcase', 'honey', 'warmth', 'saviour', 'hurricane', 'deh', 'ginger', 'endless', 'jesus', 'yi', 'apart', 'lo', 'naive', 'sugar', 'ah', 'lipstick', 'ohh', 'warm', 'midnight', 'joy', 'daylight', 'sun', 'babe', 'dawn', 'aboard', 'mi', 'wonderful', 'pony', 'eternity', 'lifetime', 'heartbreak', 'somewhere', 'lovely', 'masquerade', 'sunset', 'thump', 'firework', 'salvation', 'te', 'hee', 'praise', 'underneath', 'together', 'ohhhh', 'getaway', 'sentimental', 'sky', 'dynamite', 'du', 'emptiness', 'precious', 'tease', 'hey', 'weh', 'teenage', 'sadness', 'rescue', 'away', 'hypnotize', 'dancin', 'moon', 'doll', 'mon', 'rain', 'downtown', 'fall', 'superstar', 'rejoice', 'savior', 'melt', 'mek', 'whoa', 'sha', 'tic', 'temptation', 'river', 'magical', 'drift', 'rio', 'shy', 'sparkle', 'tokyo', 'lightning', 'heal', 'nowhere', 'hello', 'shin', 'ocean', 'awake', 'bum', 'di', 'underwater', 'bell', 'twinkle', 'linger', 'glitter', 'hymn', 'dream', 'helpless', 'memory', 'alright', 'alone', 'breathe', 'dah', 'bright', 'ling', 'colour', 'storm', 'smile', 'telephone', 'whisper', 'whirl', 'astray', 'rooftop', 'night', 'cry', 'recall', 'ache', 'rearrange', 'autumn', 'rose', 'perfume', 'getcha', 'airplane', 'afraid', 'invincible', 'pa', 'satellite', 'summer', 'hazy', 'sidewalk', 'breakdown', 'thorn', 'cruel', 'alive', 'tear', 'singin', 'scare', 'shall', 'devotion', 'wind', 'sea', 'soothe', 'baby', 'headlight', 'maybe', 'crossroad', 'illusion', 'upside', 'tender', 'bruise', 'wash', 'babylon', 'flicker', 'choir', 'radio', 'vibration', 'je', 'happy', 'close', 'along', 'parade', 'dreamin', 'rum', 'tide', 'shinin', 'fever', 'darkness', 'tangle', 'brave', 'dong', 'sometime', 'somebody', 'touch', 'runaway', 'echo', 'dem', 'heaven', 'groove', 'fairy', 'believe', 'insecure', 'heel', 'footstep', 'holiday', 'destination', 'wander', 'bloom', 'secret', 'goodness', 'hurt', 'hide', 'everythings', 'feather', 'home', 'boogie', 'unwind', 'mighty', 'flower', 'star', 'neon', 'grace', 'breathin', 'mine', 'romantic', 'doo', 'refrain', 'world', 'bye', 'haffi', 'else', 'anyway', 'halfway', 'revolve', 'dusk', 'ohhh', 'morning', 'forget', 'confusion', 'electric', 'inside', 'eye', 'lucky', 'tiny', 'asleep', 'easy', 'true', 'breeze', 'spell', 'fun', 'faithful', 'instrumental', 'shadow', 'weary', 'ribbon', 'find', 'anyone', 'romeo', 'que', 'bl ...
# 2762

# %%
with open('vocabulary.py', 'w') as file:
    file.write('vocabulary = ' + json.dumps(best_words))
